# %%
# ENTREGABLE 26/08/2022 - PIPOL - MAXIMIZACIÓN DE BENEFICIOS EN TÉRMINOS PREDICTIVOS ----------------------------------------------------------------------------------



#----------------------------- LIBRERIES & FILES UPLOADING ------------------------------------------------------------------------------------------------------------

import datetime as dt
from datetime import datetime 
from traitlets.traitlets import Dict
import math as mh
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
import random as rnd
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import pairwise_distances_argmin_min  
import io 
import scipy as spy
import statistics
from statistics import mode 
from google.colab import files 
import seaborn as sb
import openpyxl
import xlrd 

uploaded = files.upload()
print('\n')
 
file = io.BytesIO(uploaded['ENTREGABLE 26.08.2022 - PIPOL.xlsx'])


#--------------------- FUNCTIONS DEFINITIONS --------------------------------------------------------------------------------------------------------------------------


def Markov_Matrix(dataframe):
  #a = i
  neg_neg_counter = 0
  neg_zero_counter = 0
  neg_pos_counter = 0

  zero_neg_counter = 0
  zero_zero_counter = 0
  zero_pos_counter = 0

  pos_neg_counter = 0
  pos_zero_counter = 0
  pos_pos_counter = 0

  y = 0.0000001

  list_Markov_arrays = []
  
  for l in range (0, len(datos)): 
   
   cota = pd.DataFrame(dataframe, columns = ['fc_seg_duracion'])
   
   cota_nro = cota.iloc[l]['fc_seg_duracion']

   Delta = dataframe.iloc[l]['Delta ga_sessions_5m']
   if l<len(datos)-1:
     s = l+1
     Epsilon = dataframe.iloc[s]['Delta ga_sessions_5m']
   else:
     Epsilon = 0

   if (Delta < 0) and (Epsilon < 0):
     neg_neg_counter = neg_neg_counter + 1
   elif (Delta < 0) and (Epsilon == 0):
     neg_zero_counter = neg_zero_counter + 1
   elif (Delta < 0) and (Epsilon > 0):  
     neg_pos_counter = neg_pos_counter + 1

   if (Delta == 0) and (Epsilon < 0):
     zero_neg_counter = zero_neg_counter + 1
   elif (Delta == 0) and (Epsilon == 0):
     zero_zero_counter = zero_zero_counter + 1
   elif (Delta == 0) and (Epsilon > 0):
     zero_pos_counter = zero_pos_counter + 1

   if (Delta > 0) and (Epsilon < 0):
     pos_neg_counter = pos_neg_counter + 1
   elif (Delta > 0) and (Epsilon == 0):
     pos_zero_counter = pos_zero_counter + 1
   elif (Delta > 0) and (Epsilon > 0):
     pos_pos_counter = pos_pos_counter + 1

  Total_Delta_Neg = neg_neg_counter + neg_zero_counter + neg_pos_counter
  
  Total_Delta_Zero = zero_neg_counter + zero_zero_counter + zero_pos_counter
   
  Total_Delta_Pos = pos_neg_counter + pos_zero_counter + pos_pos_counter

  p00 = (neg_neg_counter) /(Total_Delta_Neg + y)         # Frecuencias condicionales, estado condicional Delta Negativo
  p01 = (neg_zero_counter)/(Total_Delta_Neg + y)
  p02 = (neg_pos_counter) /(Total_Delta_Neg + y)

  p10 = (zero_neg_counter) /(Total_Delta_Zero + y)            # Frecuencias condicionales, estado condicional Delta Nulo
  p11 = (zero_zero_counter) /(Total_Delta_Zero + y)
  p12 = (zero_pos_counter) /(Total_Delta_Zero + y)

  p20 = (pos_neg_counter) /(Total_Delta_Pos + y)              # Frecuencias condicionales, estado condicional Delta Positivo
  p21 = (pos_zero_counter) /(Total_Delta_Pos + y)
  p22 = (pos_pos_counter) /(Total_Delta_Pos + y)

  Matriz_Markov = np.array([[p00,p01,p02],[p10,p11,p12],[p20,p21,p22]])
  
  Sigma_1 = p00 + p01 + p02                               # Verificación de la condición de 'Matriz Estocástica' por cada fila/cada matriz.
  Sigma_2 = p10 + p11 + p12
  Sigma_3 = p20 + p21 + p22
  

  list_Markov_arrays.append(Matriz_Markov)

  return(Matriz_Markov)




def Markov_Matrix_search(dataframe):
  #a = i
  neg_neg_counter = 0
  neg_zero_counter = 0
  neg_pos_counter = 0

  zero_neg_counter = 0
  zero_zero_counter = 0
  zero_pos_counter = 0

  pos_neg_counter = 0
  pos_zero_counter = 0
  pos_pos_counter = 0

  y = 0.0000001

  list_Markov_search_arrays = []
  
  for l in range (0, len(datos)): 
   
   cota = pd.DataFrame(dataframe, columns = ['fc_seg_duracion'])
   
   cota_nro = cota.iloc[l]['fc_seg_duracion']

   Delta = dataframe.iloc[l]['Delta ga_sessions_search_5m']
   if l<len(datos)-1:
     s = l+1
     Epsilon = dataframe.iloc[s]['Delta ga_sessions_search_5m']
   else:
     Epsilon = 0

   if (Delta < 0) and (Epsilon < 0):
     neg_neg_counter = neg_neg_counter + 1
   elif (Delta < 0) and (Epsilon == 0):
     neg_zero_counter = neg_zero_counter + 1
   elif (Delta < 0) and (Epsilon > 0):
     neg_pos_counter = neg_pos_counter + 1

   if (Delta == 0) and (Epsilon < 0):
     zero_neg_counter = zero_neg_counter + 1
   elif (Delta == 0) and (Epsilon == 0):
     zero_zero_counter = zero_zero_counter + 1
   elif (Delta == 0) and (Epsilon > 0):
     zero_pos_counter = zero_pos_counter + 1

   if (Delta > 0) and (Epsilon < 0):
     pos_neg_counter = pos_neg_counter + 1
   elif (Delta > 0) and (Epsilon == 0):
     pos_zero_counter = pos_zero_counter + 1
   elif (Delta > 0) and (Epsilon > 0):
     pos_pos_counter = pos_pos_counter + 1


  Total_Delta_Neg = neg_neg_counter + neg_zero_counter + neg_pos_counter
  
  Total_Delta_Zero = zero_neg_counter + zero_zero_counter + zero_pos_counter
   
  Total_Delta_Pos = pos_neg_counter + pos_zero_counter + pos_pos_counter

  p00 = (neg_neg_counter) /(Total_Delta_Neg + y)         # Frecuencias condicionales, estado condicional Delta Negativo
  p01 = (neg_zero_counter)/(Total_Delta_Neg + y)
  p02 = (neg_pos_counter) /(Total_Delta_Neg + y)

  p10 = (zero_neg_counter) /(Total_Delta_Zero + y)            # Frecuencias condicionales, estado condicional Delta Nulo
  p11 = (zero_zero_counter) /(Total_Delta_Zero + y)
  p12 = (zero_pos_counter) /(Total_Delta_Zero + y)

  p20 = (pos_neg_counter) /(Total_Delta_Pos + y)              # Frecuencias condicionales, estado condicional Delta Positivo
  p21 = (pos_zero_counter) /(Total_Delta_Pos + y)
  p22 = (pos_pos_counter) /(Total_Delta_Pos + y)

  Matriz_Markov_search = np.array([[p00,p01,p02],[p10,p11,p12],[p20,p21,p22]])
  
  Sigma_1 = p00 + p01 + p02                               # Verificación de la condición de 'Matriz Estocástica' por cada fila/cada matriz.
  Sigma_2 = p10 + p11 + p12
  Sigma_3 = p20 + p21 + p22
  

  list_Markov_search_arrays.append(Matriz_Markov_search)

  return(Matriz_Markov_search)




def maxs_determination(Markov, df_max, m, datos_max, df_dataframe, datos):

  lista_de_elementos_predictive_tomados = []
  lista_probabilidades_tomadas = []
  lista_duracion_anuncio = []
  lista_dia_anuncio = []
  lista_vectores_interes = []

  for j in range (1,len(df_max)+1):

    forecast_matrix = np.linalg.matrix_power(Markov, j)
    
    Delta_0 = datos['Delta ga_sessions_5m'][j-1]


    if Delta_0 < 0:
     
       State_0_vector = [Delta_0, 0, 0]

    elif Delta_0 == 0:

       State_0_vector = [0, Delta_0, 0]
     
    elif Delta_0 > 0:

       State_0_vector = [0, 0, Delta_0]

    State_n_vector = np.matmul(State_0_vector, forecast_matrix) 
   

    Max_Probability = np.amax(forecast_matrix)       # probabilidad del evento "Delta" para esa muestra
    Min_Probability = np.amin(forecast_matrix)

    Showed_Probability = Max_Probability + Min_Probability

    if Showed_Probability < 0.999:
     Showed_Probability = Showed_Probability
    else:
     Showed_Probability = Max_Probability
  
    Showed_Probability = Showed_Probability*100
    
    elemento_tomado_predictive = np.amax(State_n_vector)
    
    lista_de_elementos_predictive_tomados.append(elemento_tomado_predictive)
    df_lista_de_elementos_predictive_tomados = pd.DataFrame(lista_de_elementos_predictive_tomados)
    
    lista_probabilidades_tomadas.append(Showed_Probability)
    df_lista_probabilidades_tomadas = pd.DataFrame(lista_probabilidades_tomadas)
    

    lista_dia_anuncio.append(datos['desc_tie_dia_anio'][j-1]-65)

    vector_de_interes = [datos['desc_tie_dia_anio'][j-1]-65, df_max['fc_costo_usd_monto'][j-1], elemento_tomado_predictive, Showed_Probability]
    
    lista_vectores_interes.append(vector_de_interes)
  df_vectores_interes = pd.DataFrame(lista_vectores_interes)
  df_vectores_interes.columns = ['día','Cost', 'Delta', 'Prob.']
  
  frame_compuesto = pd.concat([df_lista_de_elementos_predictive_tomados, df_lista_probabilidades_tomadas, datos_max, df_max['fc_costo_usd_monto'], df_dataframe['fc_seg_duracion']], axis = 1)
  
  frame_compuesto.columns = ['max.', 'prob.', 'día', 'Cost', 'seg.']

  return(frame_compuesto, df_vectores_interes, lista_vectores_interes)



def Ordenamiento_x_dia (lista_de_vectores, lista_de_listas):
  
  lista_de_listas = []
  lista_por_dia = []
  lista_etiquetas_x_dia = []
  vector_nulo = [0,0,0,0] 
  lista_completa = []

  for k in range(1, 154):                                          # ciclo "for" para la generación de la lista de etiquetas de cada día
   lista_etiquetas_x_dia.append(k)
  
  for g in range(0, 154):                                           # generando lista de listas vacías
   lista_de_listas.append(lista_por_dia)   

  for j in range(0,len(lista_de_vectores)):
   vector = lista_de_vectores[j] 
  
   
   for g in range(0, 154):                                           # agrupo los vectores de c/lista según los días en orden desde el 0 al 153
     if vector[0] == g:                                              # evaluando la primera componente del vector de la lista tomada para c/costo
      posicion_dia = list(lista_de_listas[g])
      posicion_dia.append(vector)
      lista_de_listas[g] = posicion_dia

  return(lista_de_listas)



def agrupamiento_por_día(df_frame_max, lista_de_los_max_para_cada_dia):
  
  for h in range(0, 154):
   
     if h == df_frame_max[0]:
       lista_de_los_max_para_cada_dia[h].append(df_frame_max)

  return(lista_de_los_max_para_cada_dia)


#----------------------------------------------------------------------------------------------------------------------------------------------------------------------



#---------------- MAIN BODY OF THE PROGRAM ----------------------------------------------------------------------------------------------------------------------------

list_Markov_arrays = []
list_Markov_search_arrays = []
lista_dias = []
lista_maximos = []
lista_maximos_search = []
lista_de_listas = []
lista_de_listas_SEARCH = []
lst_segun_costos = []
DATA_FRAMES = []
lista_de_los_max_para_cada_dia = []
lista_de_los_max_para_cada_dia_SEARCH = []

for m in range(0,154):
 lista_de_los_max_para_cada_dia.append([])
 lista_de_los_max_para_cada_dia_SEARCH.append([])
                                              
df_inicial = pd.DataFrame()
df_concats = pd.DataFrame()
df_tomado_x_dia = pd.DataFrame()

for j in range(2,14):
 
 file_labels = ['Hoja2','Hoja3','Hoja4','Hoja5','Hoja6','Hoja7','Hoja8','Hoja9','Hoja10','Hoja11','Hoja12','Hoja13']
 datos = pd.read_excel(file, sheet_name = file_labels[j-2])
 datos = pd.DataFrame(datos, columns = ['fc_costo_usd_monto','desc_tie_dia_anio','desc_tie_fecha','fc_seg_duracion','ga_sessions_pre_5m','ga_sessions_post_5m','Delta ga_sessions_5m','','ga_sessions_search_pre_5m','ga_sessions_search_post_5m','Delta ga_sessions_search_5m','desc_tie_hora'])
 dataframe = pd.DataFrame(datos, columns = ['fc_seg_duracion', 'Delta ga_sessions_5m'])
 dataframe_search = pd.DataFrame(datos, columns = ['fc_seg_duracion', 'Delta ga_sessions_search_5m'])
 df_max = pd.DataFrame(datos, columns = ['fc_costo_usd_monto', 'Delta ga_sessions_5m'])
 df_max_search = pd.DataFrame(datos, columns = ['fc_costo_usd_monto', 'Delta ga_sessions_search_5m'])
 datos_max = datos['desc_tie_dia_anio']-65

 #print('dataframe', dataframe)

 deltas_relativos_ga_sessions = [x for x in datos['Delta ga_sessions_5m'] if mh.isnan(x) == False]
 deltas_relativos_ga_sessions = pd.DataFrame(deltas_relativos_ga_sessions)

 deltas_relativos_ga_sessions_search = [x for x in datos['Delta ga_sessions_search_5m'] if mh.isnan(x) == False]
 deltas_relativos_ga_sessions_search = pd.DataFrame(deltas_relativos_ga_sessions_search)

 #-------------------------------------------------------------------------------------------
 REF = datos['Delta ga_sessions_5m']*0
 plt.figure(figsize = (30,10))
 plt.plot(datos['desc_tie_dia_anio']-66,datos['Delta ga_sessions_5m'], color = 'orange')
 plt.plot(datos['desc_tie_dia_anio']-66,datos['Delta ga_sessions_search_5m'], color = 'darkorchid')
 plt.plot(datos['desc_tie_dia_anio']-66, REF, c = 'red')
 plt.grid(False)
 plt.show()
 print('\n')
 #-------------------------------------------------------------------------------------------
 
 a = 1                                       # calcula la matriz de prob. conforme a la duración en segundos de los anuncios --para este caso sólo se consideran 2 duraciones
 Markov = Markov_Matrix(dataframe)
 Markov_search = Markov_Matrix_search(dataframe_search)
 
 lista_file_sheets_organica = ['0','0','búsqueda orgnánica 0.xlsx','búsqueda orgnánica 1.xlsx','búsqueda orgnánica 2.xlsx','búsqueda orgnánica 3.xlsx','búsqueda orgnánica 4.xlsx','búsqueda orgnánica 5.xlsx','búsqueda orgnánica 6.xlsx','búsqueda orgnánica 7.xlsx', 'búsqueda orgnánica 8.xlsx','búsqueda orgnánica 9.xlsx','búsqueda orgnánica 10.xlsx','búsqueda orgnánica 11.xlsx','búsqueda orgnánica 12.xlsx','búsqueda orgnánica 13.xlsx']

 lista_maximos.append(maxs_determination(Markov, df_max, j, datos_max, dataframe, datos)[0]) #.set_index('día'))
 
 Ordenamiento_organica = Ordenamiento_x_dia(maxs_determination(Markov, df_max, j, datos_max, dataframe, datos)[2], lista_de_listas)

 df_frames = []
 list_df_frame_atom = []
 lst_segun_costos = []

 print('              day  us$      delta org. %     prob. org. ')

 for l in range(0,154):
  
  df_frame = Ordenamiento_x_dia(maxs_determination(Markov, df_max, j, datos_max, dataframe, datos)[2], lista_de_listas)[l]  # columns = ['day', 'US$', 'Delta%', 'Prob.'])
  
  list_df_frame_atom = []

  if len(df_frame) >= 1:
   
   for r in range (0, len(df_frame)):
    df_frame_atom = df_frame[r]                            # elijo vector de la lista "df_frame"
    list_df_frame_atom.append(df_frame_atom[3])            # tomo el cuarto elemento del vector elegido
   
   element_df_frame_max = max(list_df_frame_atom)           # obtengo el máximo de la lista de los cuartos elementos de la lista de vectores sacada de la lista de lista de vectores.
   index = list_df_frame_atom.index(element_df_frame_max)   # obtengo la posición del máximo    
   df_frame_max = df_frame[index]                           # elijo el vector que tiene el cuarto elemento (Probabilidad) máxima de la lista de vectores para cada día "df_frame".
   
   print('df_frame_max', df_frame_max, 'index', index)

   lista_de_los_max_para_cada_dia = agrupamiento_por_día(df_frame_max, lista_de_los_max_para_cada_dia)


 print('\n')
 print('              day  us$      delta search %    prob. search ')

 for l in range(0,154):
  
  df_frame = Ordenamiento_x_dia(maxs_determination(Markov_search, df_max_search, j, datos_max, dataframe_search, datos)[2], lista_de_listas_SEARCH)[l]  # columns = ['day', 'US$', 'Delta%', 'Prob.'])
  
  list_df_frame_atom = []

  if len(df_frame) >= 1:
   
   for r in range (0, len(df_frame)):
    df_frame_atom = df_frame[r]                            # elijo vector de la lista "df_frame"
    list_df_frame_atom.append(df_frame_atom[3])            # tomo el cuarto elemento del vector elegido, EL DE MÁXIMA PROBABILIDAD
    
   element_df_frame_max = max(list_df_frame_atom)           # obtengo el máximo de la lista de los cuartos elementos de la lista de vectores sacada de la lista de lista de vectores.
   index = list_df_frame_atom.index(element_df_frame_max)   # obtengo la posición del máximo    
   df_frame_max_search = df_frame[index]                           # elijo el vector que tiene el cuarto elemento (Probabilidad) máxima de la lista de vectores para cada día "df_frame".
   
   print('df_frame_max', df_frame_max_search, 'index', index)

   lista_de_los_max_para_cada_dia_SEARCH = agrupamiento_por_día(df_frame_max_search, lista_de_los_max_para_cada_dia_SEARCH)
 
 print('\n')


print('              DataFrames Format Presentation')
print('\n')

for d in range(0,154):
  
  block_x_dia = lista_de_los_max_para_cada_dia[d]
  block_x_dia_SEARCH = lista_de_los_max_para_cada_dia_SEARCH[d]

  resultantList = []                          #elimino los vectores duplicados
  for element in block_x_dia:
    if element not in resultantList:
        resultantList.append(element)
  block_x_dia = resultantList       

  df_block_x_dia = pd.DataFrame(block_x_dia, columns = ['day', 'us$', 'delta % Organic', 'prob % Organic'])

  if df_block_x_dia.empty:
     del block_x_dia

          # * * *  --------------------------------------------------------------------------  * * * #
    
  resultantList_search = []                          #elimino los vectores duplicados
  for element in block_x_dia_SEARCH:
    if element not in resultantList_search:
        resultantList_search.append(element)
  block_x_dia_SEARCH = resultantList_search       

  df_block_x_dia_SEARCH = pd.DataFrame(block_x_dia_SEARCH, columns = ['day search', 'us$ search', 'delta % search', 'prob % search'])

  if df_block_x_dia_SEARCH.empty:
     del block_x_dia_SEARCH

  else:   
   melted_dfs = pd.concat([df_block_x_dia, df_block_x_dia_SEARCH], axis = 1) 
   print(melted_dfs.drop(['day search', 'us$ search'], axis=1))          
   print('\n')


#----------------- Scatter plots 3D ------------------------------------------------------------------------------------------------#


#---------------------------------------- ORGANICA ---------------------------------------------------------------------------------#

lista_x1 = []

lista_x2 = []

lista_x3 = []


print('\n')
print('\n')
print('\n')
print('\n')


lista_asignacion_colores = []

costos1 = []
costos2 = []
costos3 = []


for l in range(0,12):
  
  costos1.append([])
  costos2.append([])
  costos3.append([])


for d in range(0,154):     
  
  block_x_dia = agrupamiento_por_día(df_frame_max, lista_de_los_max_para_cada_dia)[d]
   
  resultantList = []                          #elimino los vectores duplicados
  for element in block_x_dia:
    if element not in resultantList:
        resultantList.append(element)
  block_x_dia = resultantList                                            
  
  
  lista_de_costos = [109.12, 113.20, 152.82, 158.40, 33.90, 47.50, 54.56, 56.60, 67.80, 76.41, 79.20, 95.00]
  lista_de_colores = ['#6495ED', '#7FFFD4', '#F0FFFF', '#FF7F50', '#F0F8FF', '#DC143C', '#8A2BE2', '#CD853F', '#FF69B4', '#FF4500', '#FFD700', '#4B0082']
  
  for j in range(0,len(block_x_dia)):
   
   vector = block_x_dia[j]
  
   x1 = vector[0]               # variable independiente: día 

   x2 = vector[1]               # v.i: us$

   x3 = vector[2]               # v.i: delta%
 
   for q in range(0,12):                               # para cada COSTO su COLOR
     
     if x2 == lista_de_costos[q]: 
       
       color = lista_de_colores[q]
      
       costos1[q].append(x1)

       costos2[q].append(x2)        #lista_asignacion_colores.append(color)
       
       costos3[q].append(x3)

#---------------------------------------- SEARCH -----------------------------------------------------------------------------------#

costos1_search = []
costos2_search = []
costos3_search = []


for l in range(0,12):
  
  costos1_search.append([])
  costos2_search.append([])
  costos3_search.append([])


for d in range(0,154):     
  
  block_x_dia_SEARCH = agrupamiento_por_día(df_frame_max_search, lista_de_los_max_para_cada_dia_SEARCH)[d]
   
  resultantList = []                          #elimino los vectores duplicados
  for element in block_x_dia_SEARCH:
    if element not in resultantList_search:
        resultantList_search.append(element)
  block_x_dia_SEARCH = resultantList_search                                           

  
  lista_de_costos = [109.12, 113.20, 152.82, 158.40, 33.90, 47.50, 54.56, 56.60, 67.80, 76.41, 79.20, 95.00]
  lista_de_colores = ['#6495ED', '#7FFFD4', '#F0FFFF', '#FF7F50', '#F0F8FF', '#DC143C', '#8A2BE2', '#CD853F', '#FF69B4', '#FF4500', '#FFD700', '#4B0082']
  
  for j in range(0,len(block_x_dia_SEARCH)):
   
   vector = block_x_dia_SEARCH[j]
  
   x1 = vector[0]               # variable independiente: día 

   x2 = vector[1]               # v.i: us$

   x3 = vector[2]               # v.i: delta%
 
   for q in range(0,12):                               # para cada COSTO su COLOR
     
     if x2 == lista_de_costos[q]: 
       
       color = lista_de_colores[q]
      
       costos1_search[q].append(x1)

       costos2_search[q].append(x2)        #lista_asignacion_colores.append(color)
       
       costos3_search[q].append(x3)




fig = plt.figure(figsize = (30,20))

ax = fig.add_subplot(111, projection ='3d')

ax = Axes3D(fig)

plt.title("(DAYS)  vs  (US$)  vs  (DELTA %) - BÚSQUEDA ORGÁNICA", fontweight ='bold', color='black', weight='normal', size = 24)
ax.set_xlabel('days', fontweight ='bold', color='black', weight='normal', size = 18)
ax.set_ylabel('us$', fontweight ='bold', color='black', weight='normal', size = 18)
ax.set_zlabel('delta %', fontweight ='bold', color='black', weight='normal', size = 18)

ax.scatter3D(costos1[0], costos2[0], costos3[0], c = '#6495ED', label = '109.12', s=600, alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[1], costos2[1], costos3[1], c = 'chartreuse', label = '113.20', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[2], costos2[2], costos3[2], c = 'palevioletred', label = '152.82', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[3], costos2[3], costos3[3], c = 'green', label = '158.40', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[4], costos2[4], costos3[4], c = 'goldenrod', label = '33.90', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[5], costos2[5], costos3[5], c = '#DC143C', label = '47.50', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[6], costos2[6], costos3[6], c = '#8A2BE2', label = '54.56', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[7], costos2[7], costos3[7], c = 'teal', label = '56.60', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[8], costos2[8], costos3[8], c = '#FF69B4', label = '67.80', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[9], costos2[9], costos3[9], c = '#FF4500', label = '76.41', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[10], costos2[10], costos3[10], c = '#FFD700', label = '79.20', s=600, alpha=0.7) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[11], costos2[11], costos3[11], c =  '#4B0082', label = '95.00', s=600, alpha=0.7)   
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

plt.show()



fig = plt.figure(figsize = (30,20))

ax = fig.add_subplot(111, projection ='3d')

ax = Axes3D(fig)

plt.title("(DAYS)  vs  (US$)  vs  (DELTA %) - GOOGLE SEARCH", fontweight ='bold', color='black', weight='normal', size = 24)
ax.set_xlabel('days', fontweight ='bold', color='black', weight='normal', size = 18)
ax.set_ylabel('us$', fontweight ='bold', color='black', weight='normal', size = 18)
ax.set_zlabel('delta %', fontweight ='bold', color='black', weight='normal', size = 18)


ax.scatter3D(costos1_search[0], costos2_search[0], costos3_search[0], c = '#6495ED', label = '109.12', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[1], costos2_search[1], costos3_search[1], c = 'chartreuse', label = '113.20', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[2], costos2_search[2], costos3_search[2], c = 'palevioletred', label = '152.82', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[3], costos2_search[3], costos3_search[3], c = 'green', label = '158.40', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[4], costos2_search[4], costos3_search[4], c = 'goldenrod', label = '33.90', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[5], costos2_search[5], costos3_search[5], c = '#DC143C', label = '47.50', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[6], costos2_search[6], costos3_search[6], c = '#8A2BE2', label = '54.56', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[7], costos2_search[7], costos3_search[7], c = 'teal', label = '56.60', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[8], costos2_search[8], costos3_search[8], c = '#FF69B4', label = '67.80', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[9], costos2_search[9], costos3_search[9], c = '#FF4500', label = '76.41', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[10], costos2_search[10], costos3_search[10], c = '#FFD700', label = '79.20', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[11], costos2_search[11], costos3_search[11], c =  '#4B0082', label = '95.00', s=300, marker ='x', alpha=0.7) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14
 
plt.show()




fig = plt.figure(figsize = (30,20))

ax = fig.add_subplot(111, projection ='3d')

ax = Axes3D(fig)

plt.title("(DAYS)  vs  (US$)  vs  (DELTA %) - ORGÁNICA & GOOGLE SEARCH", fontweight ='bold', color='black', weight='normal', size = 24)
ax.set_xlabel('days', fontweight ='bold', color='black', weight='normal', size = 18)
ax.set_ylabel('us$', fontweight ='bold', color='black', weight='normal', size = 18)
ax.set_zlabel('delta %', fontweight ='bold', color='black', weight='normal', size = 18)

ax.scatter3D(costos1[0], costos2[0], costos3[0], c = '#6495ED', label = '109.12', s=600, alpha=0.3) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[1], costos2[1], costos3[1], c = 'chartreuse', label = '113.20', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[2], costos2[2], costos3[2], c = 'palevioletred', label = '152.82', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[3], costos2[3], costos3[3], c = 'green', label = '158.40', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[4], costos2[4], costos3[4], c = 'goldenrod', label = '33.90', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[5], costos2[5], costos3[5], c = '#DC143C', label = '47.50', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[6], costos2[6], costos3[6], c = '#8A2BE2', label = '54.56', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[7], costos2[7], costos3[7], c = 'teal', label = '56.60', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[8], costos2[8], costos3[8], c = '#FF69B4', label = '67.80', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[9], costos2[9], costos3[9], c = '#FF4500', label = '76.41', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[10], costos2[10], costos3[10], c = '#FFD700', label = '79.20', s=600, alpha=0.3) 
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1[11], costos2[11], costos3[11], c =  '#4B0082', label = '95.00', s=600, alpha=0.3)   
plt.legend(fontsize = 14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[0], costos2_search[0], costos3_search[0], c = '#6495ED', label = '109.12', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[1], costos2_search[1], costos3_search[1], c ='chartreuse', label = '113.20', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[2], costos2_search[2], costos3_search[2], c = 'palevioletred', label = '152.82', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[3], costos2_search[3], costos3_search[3], c = 'green', label = '158.40', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[4], costos2_search[4], costos3_search[4], c = 'goldenrod', label = '33.90', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[5], costos2_search[5], costos3_search[5], c = '#DC143C', label = '47.50', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[6], costos2_search[6], costos3_search[6], c = '#8A2BE2', label = '54.56', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[7], costos2_search[7], costos3_search[7], c = 'teal', label = '56.60', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[8], costos2_search[8], costos3_search[8], c = '#FF69B4', label = '67.80', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[9], costos2_search[9], costos3_search[9], c = '#FF4500', label = '76.41', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[10], costos2_search[10], costos3_search[10], c = '#FFD700', label = '79.20', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14

ax.scatter3D(costos1_search[11], costos2_search[11], costos3_search[11], c =  '#4B0082', label = '95.00', s=300, marker ='x', alpha=0.6) 
plt.legend(fontsize=14)
plt.rcParams['legend.handlelength'] = 14
  
plt.show()


print('\n')
print('\n')
print('\n')
print('\n')
print('\n')
print('\n')
print('\n')
# Out:
#      <input type="file" id="files-440b94db-4986-4a72-889d-0b904389dcbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-440b94db-4986-4a72-889d-0b904389dcbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ENTREGABLE 26.08.2022 - PIPOL.xlsx to ENTREGABLE 26.08.2022 - PIPOL (2).xlsx
#               day  us$      delta org. %     prob. org.
# df_frame_max [117, 109.12, 9.999999500000026, 99.99999000000099] index 0
# df_frame_max [118, 109.12, 0.0, 49.99999250000088] index 0
# df_frame_max [119, 109.12, 7.142855714285912, 49.99998750000213] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [117, 109.12, 19.999998000000197, 99.99999000000099] index 0
# df_frame_max [118, 109.12, -10.714284642857226, 49.99999250000088] index 0
# df_frame_max [119, 109.12, 0.0, 24.999995000000695] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [2, 113.2, 0.0, 74.99999906250001] index 0
# df_frame_max [4, 113.2, 0.0, 71.50051496258104] index 0
# df_frame_max [9, 113.2, -19.865627305842118, 71.10988908976825] index 0
# df_frame_max [12, 113.2, 40.89884394161638, 70.45193755798623] index 0
# df_frame_max [30, 113.2, 0.0, 70.37555623736442] index 0
# df_frame_max [31, 113.2, 40.74073086118317, 70.37036850001279] index 0
# df_frame_max [44, 113.2, 0.0, 70.37036165080391] index 0
# df_frame_max [50, 113.2, 24.444440791203665, 70.37036049172264] index 0
# df_frame_max [62, 113.2, 20.370366994613683, 70.37035864565404] index 0
# df_frame_max [67, 113.2, -11.851849739801214, 70.37035787778767] index 0
# df_frame_max [68, 113.2, 8.148146619281443, 70.37035709474311] index 0
# df_frame_max [69, 113.2, -9.876541119224038, 70.37035553115973] index 0
# df_frame_max [70, 113.2, -5.925924539856404, 70.37035396738453] index 0
# df_frame_max [74, 113.2, 61.11109421353703, 70.37035083981391] index 0
# df_frame_max [76, 113.2, -21.548815071982858, 70.37034927602838] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [2, 113.2, 0.0, 74.99999812500005] index 0
# df_frame_max [4, 113.2, 0.0, 75.28698820030637] index 0
# df_frame_max [9, 113.2, -12.971307534113212, 75.48856246254114] index 0
# df_frame_max [12, 113.2, 0.0, 75.29702100043052] index 1
# df_frame_max [30, 113.2, 0.0, 75.29415866230805] index 0
# df_frame_max [31, 113.2, 56.47058114309404, 75.29410789698775] index 0
# df_frame_max [44, 113.2, 0.0, 75.29410698813984] index 0
# df_frame_max [50, 113.2, 33.882347891623596, 75.29410609851459] index 0
# df_frame_max [62, 113.2, 28.235289245373018, 75.29410432631524] index 0
# df_frame_max [67, 113.2, -7.5294103253635125, 75.29410344049175] index 0
# df_frame_max [68, 113.2, 11.294115432405675, 75.2941025546772] index 0
# df_frame_max [69, 113.2, -6.274508383016654, 75.29410078305104] index 0
# df_frame_max [70, 113.2, -3.7647049412287, 75.29409901142516] index 0
# df_frame_max [74, 113.2, 84.70585777072624, 75.29409546817354] index 0
# df_frame_max [76, 113.2, -13.68983518358121, 75.29409369654778] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [117, 152.82, -6.349206278659612, 66.66666444444452] index 0
# df_frame_max [118, 152.82, 0.0, 66.41975051824426] index 0
# df_frame_max [119, 152.82, 11.175253176252792, 62.51985556425335] index 0
# df_frame_max [121, 152.82, 14.911238309964872, 62.136070327172575] index 0
# df_frame_max [123, 152.82, 44.73660790277139, 62.10746297109393] index 1
# df_frame_max [125, 152.82, 44.73681944314817, 62.10541077453329] index 1
# df_frame_max [126, 152.82, -6.94736628248834, 62.10526297030216] index 1
# df_frame_max [128, 152.82, 62.63156787974084, 62.10525087680679] index 0
# df_frame_max [130, 152.82, 14.91227771941845, 62.10525078736529] index 0
# df_frame_max [132, 152.82, -2.89473623812493, 62.105249560686474] index 0
# df_frame_max [133, 152.82, 0.0, 62.105248786047355] index 0
# df_frame_max [135, 152.82, -11.05262892565103, 62.10524785103635] index 0
# df_frame_max [137, 152.82, -4.962404750751227, 62.10524696177643] index 0
# df_frame_max [139, 152.82, 33.55262250284624, 62.10524606031623] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [117, 152.82, -4.761904722222222, 59.99999880000002] index 0
# df_frame_max [118, 152.82, -17.20833268631946, 74.33332972111124] index 1
# df_frame_max [119, 152.82, 0.0, 73.89088321505952] index 1
# df_frame_max [121, 152.82, 16.767124388886575, 73.75370435941522] index 0
# df_frame_max [123, 152.82, 12.561762745391425, 73.83149372625718] index 0
# df_frame_max [125, 152.82, -5.889654008792897, 73.82329407234342] index 0
# df_frame_max [126, 152.82, -5.889996519690688, 73.82215923173784] index 0
# df_frame_max [128, 152.82, 70.36642434294038, 73.82200061267707] index 0
# df_frame_max [130, 152.82, 16.75392808559563, 73.82194952592718] index 0
# df_frame_max [132, 152.82, -3.9267000559547283, 73.82197689483229] index 0
# df_frame_max [133, 152.82, 0.0, 73.82196889377201] index 0
# df_frame_max [135, 152.82, -14.992856636951357, 73.82197181862583] index 0
# df_frame_max [137, 152.82, -6.73148678547211, 73.82197029907255] index 0
# df_frame_max [139, 152.82, 37.69632461948109, 73.82196960656336] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [1, 158.4, -4.242424235996327, 57.57575748852158] index 0
# df_frame_max [2, 158.4, -9.345020293815978, 57.54109965088136] index 2
# df_frame_max [3, 158.4, -4.153342545292353, 57.541099990883296] index 0
# df_frame_max [4, 158.4, 22.54053603688478, 57.54109961818201] index 0
# df_frame_max [5, 158.4, -2.49200550438655, 57.54109927483576] index 0
# df_frame_max [8, 158.4, -7.120015712657792, 57.54109916039288] index 0
# df_frame_max [9, 158.4, -5.34001176325196, 57.541098931507136] index 0
# df_frame_max [10, 158.4, 67.62160676573568, 57.54109847373565] index 0
# df_frame_max [11, 158.4, 67.62160636226002, 57.54109813040704] index 0
# df_frame_max [12, 158.4, -3.1150067937475376, 57.54109767263556] index 0
# df_frame_max [22, 158.4, -6.230013562713461, 57.54109744374981] index 0
# df_frame_max [23, 158.4, -5.340011572079508, 57.541096871535466] index 0
# df_frame_max [24, 158.4, 45.08106938393201, 57.541096184878256] index 0
# df_frame_max [25, 158.4, 0.0, 57.54109572710679] index 0
# df_frame_max [29, 158.4, 45.081068576980734, 57.54109515489246] index 0
# df_frame_max [30, 158.4, 0.0, 57.54109446823528] index 0
# df_frame_max [22, 158.4, -10.852787802849539, 65.2720440339736] index 0
# df_frame_max [23, 158.4, -9.302389453474456, 65.27204338966442] index 0
# df_frame_max [24, 158.4, 43.566467504129214, 65.27204261649342] index 0
# df_frame_max [25, 158.4, 0.0, 65.2720421010461] index 0
# df_frame_max [29, 158.4, 43.566466730038336, 65.27204145673696] index 0
# df_frame_max [30, 158.4, 0.0, 65.27204068356599] index 0
# df_frame_max [31, 158.4, 0.0, 65.27204016811868] index 0
# df_frame_max [44, 158.4, 32.67484914442276, 65.27203965267138] index 0
# df_frame_max [45, 158.4, -10.852786945814886, 65.27203887950044] index 0
# df_frame_max [46, 158.4, 24.895122617020565, 65.27203823519132] index 0
# df_frame_max [47, 158.4, 21.783232203882903, 65.27203797746768] index 0
# df_frame_max [60, 158.4, -14.470382251606006, 65.27203733315858] index 0
# df_frame_max [61, 158.4, 29.044309089116656, 65.2720368177113] index 0
# df_frame_max [62, 158.4, -2.7131966293243974, 65.27203630226403] index 0
# df_frame_max [63, 158.4, -3.6175954629141343, 65.2720355290931] index 0
# df_frame_max [67, 158.4, 14.522154085837855, 65.27203475592222] index 0
# df_frame_max [68, 158.4, -6.201592111948357, 65.27203436933677] index 0
# df_frame_max [69, 158.4, -5.426393065816018, 65.27203398275132] index 0
# df_frame_max [70, 158.4, 10.891615327850653, 65.27203333844224] index 0
# df_frame_max [74, 158.4, -10.8527859173734, 65.2720326941332] index 0
# df_frame_max [75, 158.4, 26.13987637399316, 65.27203230754776] index 0
# df_frame_max [76, 158.4, -15.785870238281051, 65.27203192096233] index 0
# df_frame_max [77, 158.4, -12.058650781238633, 65.27203140551511] index 0
# df_frame_max [78, 158.4, -6.201591781377895, 65.27203089006787] index 0
# df_frame_max [79, 158.4, 54.45807448900117, 65.27203076120605] index 0
# df_frame_max [81, 158.4, -4.3411142298238365, 65.27203063234425] index 0
# df_frame_max [82, 158.4, 12.447559784903031, 65.27203024575883] index 0
# df_frame_max [83, 158.4, -3.617595141526184, 65.27202973031162] index 0
# df_frame_max [84, 158.4, 6.223779806441435, 65.27202934372619] index 0
# df_frame_max [85, 158.4, 5.4458072983824755, 65.27202895714078] index 0
# df_frame_max [86, 158.4, -4.341114109839008, 65.27202882827898] index 0
# df_frame_max [87, 158.4, -3.100795786620473, 65.27202869941718] index 0
# df_frame_max [88, 158.4, 0.0, 65.27202857055538] index 0
# df_frame_max [92, 158.4, 54.45807255377436, 65.27202844169356] index 0
# df_frame_max [93, 158.4, 32.67484346775706, 65.27202831283176] index 0
# df_frame_max [94, 158.4, 217.83228935499662, 65.27202818396995] index 0
# df_frame_max [95, 158.4, 65.34968667748389, 65.27202805510817] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [23, 33.9, 45.8333330787037, 74.99999906250002] index 0
# df_frame_max [50, 33.9, 38.37448519147233, 72.76234507726767] index 0
# df_frame_max [56, 33.9, 0.0, 72.70447376323521] index 0
# df_frame_max [57, 33.9, -9.550476457889228, 72.6271944296237] index 0
# df_frame_max [58, 33.9, 0.0, 72.62487152450163] index 0
# df_frame_max [60, 33.9, -4.789034354652358, 72.62160413281] index 0
# df_frame_max [61, 33.9, -8.211032985083467, 72.62150495701117] index 0
# df_frame_max [62, 33.9, -9.579236096298736, 72.62136692807061] index 0
# df_frame_max [63, 33.9, 233.00969369487606, 72.62135445575998] index 0
# df_frame_max [69, 33.9, 58.2524228304259, 72.62135384980381] index 0
# df_frame_max [70, 33.9, -2.873786076113798, 72.62135062904443] index 0
# df_frame_max [76, 33.9, -3.1930954982971973, 72.62134740338743] index 0
# df_frame_max [77, 33.9, -7.184464658424834, 72.6213452529495] index 0
# df_frame_max [83, 33.9, 14.563103766835193, 72.62134417773056] index 0
# df_frame_max [84, 33.9, 0.0, 72.62134274410535] index 0
# df_frame_max [85, 33.9, 29.126206671195327, 72.62134202729276] index 0
# df_frame_max [86, 33.9, -9.143863659447682, 72.62134166888646] index 0
# df_frame_max [87, 33.9, 0.0, 72.62134131048016] index 0
# df_frame_max [88, 33.9, 19.417470730807974, 72.62134059366757] index 0
# df_frame_max [89, 33.9, -3.592232081011262, 72.62134023526127] index 0
# df_frame_max [90, 33.9, 233.00964531979565, 72.62133951844869] index 0
# df_frame_max [91, 33.9, -4.105408031800344, 72.62133916004242] index 0
# df_frame_max [94, 33.9, -4.789642680128863, 72.62133880163613] index 0
# df_frame_max [95, 33.9, 116.50482035996446, 72.62133808482358] index 0
# df_frame_max [127, 33.9, 0.0, 72.6213377264173] index 0
# df_frame_max [129, 33.9, 14.563102401249726, 72.62133736801101] index 0
# df_frame_max [133, 33.9, -2.394821280968922, 72.62133700960473] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [23, 33.9, 31.249999869791665, 59.99999979999999] index 0
# df_frame_max [50, 33.9, 31.018518225308636, 62.08333232847223] index 0
# df_frame_max [56, 33.9, 0.0, 61.6805542484028] index 0
# df_frame_max [57, 33.9, -9.852623270354295, 61.57522971333626] index 0
# df_frame_max [58, 33.9, 0.0, 61.575551326072045] index 0
# df_frame_max [60, 33.9, -4.926140653893744, 61.5762813631654] index 0
# df_frame_max [61, 33.9, -8.4447616946064, 61.57635074019508] index 0
# df_frame_max [62, 33.9, -9.852216481513834, 61.576352882516574] index 0
# df_frame_max [63, 33.9, 187.1921061327522, 61.57635062814825] index 0
# df_frame_max [69, 33.9, 46.798026064419076, 61.57635001143306] index 0
# df_frame_max [70, 33.9, -2.9556646726403395, 61.57634723594755] index 0
# df_frame_max [76, 33.9, -3.2840717104633694, 61.57634446046198] index 0
# df_frame_max [77, 33.9, -7.389161126503746, 61.576342610138354] index 0
# df_frame_max [83, 33.9, 11.699504934077975, 61.57634168497657] index 0
# df_frame_max [84, 33.9, 0.0, 61.57634045142753] index 0
# df_frame_max [85, 33.9, 23.399009165033004, 61.57633983465301] index 0
# df_frame_max [86, 33.9, -9.404386417286043, 61.576339526265755] index 0
# df_frame_max [87, 33.9, 0.0, 61.576339217878505] index 0
# df_frame_max [88, 33.9, 15.599339130856254, 61.576338601104005] index 0
# df_frame_max [89, 33.9, -3.6945803042065775, 61.576338292716756] index 0
# df_frame_max [90, 33.9, 187.19206675778338, 61.576337675942284] index 0
# df_frame_max [91, 33.9, -4.22237742708214, 61.576337367555034] index 0
# df_frame_max [94, 33.9, -4.926106973591517, 61.576337059167784] index 0
# df_frame_max [95, 33.9, 93.59603150389727, 61.57633644239332] index 0
# df_frame_max [127, 33.9, 0.0, 61.576336134006084] index 0
# df_frame_max [129, 33.9, 11.69950382080001, 61.57633582561884] index 0
# df_frame_max [133, 33.9, -2.463053425118311, 61.576335517231605] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [23, 47.5, 35.15624989013672, 64.28571405612244] index 0
# df_frame_max [46, 47.5, -8.364163704481657, 60.86490475888563] index 0
# df_frame_max [57, 47.5, -3.430800034810974, 60.83867755486385] index 0
# df_frame_max [58, 47.5, 0.0, 60.86571015836676] index 0
# df_frame_max [60, 47.5, -5.561411109796513, 60.8687769324089] index 0
# df_frame_max [61, 47.5, 130.8787057953121, 60.87193424858849] index 0
# df_frame_max [62, 47.5, -4.3115195904555845, 60.872525180909996] index 4
# df_frame_max [63, 47.5, -14.371732648356012, 60.872525467026286] index 0
# df_frame_max [69, 47.5, 0.0, 60.872524708862166] index 0
# df_frame_max [70, 47.5, 29.08429591371678, 60.872522325447555] index 0
# df_frame_max [76, 47.5, -4.31151947495061, 60.872519954033365] index 0
# df_frame_max [77, 47.5, -3.4492154903796344, 60.87251837309064] index 0
# df_frame_max [82, 47.5, -5.748692359548208, 60.87251705563841] index 0
# df_frame_max [83, 47.5, 10.90660988181527, 60.87251626516708] index 0
# df_frame_max [84, 47.5, 21.813219291531205, 60.87251494771488] index 0
# df_frame_max [85, 47.5, -6.898430413413896, 60.87251336677228] index 0
# df_frame_max [86, 47.5, 14.5421457537281, 60.872513103281854] index 0
# df_frame_max [87, 47.5, -11.497383873055085, 60.872512576301006] index 0
# df_frame_max [90, 47.5, 174.5057460233017, 60.87251204932016] index 0
# df_frame_max [91, 47.5, -4.9274501673230064, 60.87251178582973] index 0
# df_frame_max [92, 47.5, 0.0, 60.87251152233931] index 0
# df_frame_max [93, 47.5, 14.542145250155514, 60.87251099535847] index 0
# df_frame_max [94, 47.5, 4.847381729069647, 60.872510731868054] index 0
# df_frame_max [95, 47.5, -6.4672782046413815, 60.87251046837764] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [23, 47.5, 29.20110167107252, 67.39618352975131] index 1
# df_frame_max [46, 47.5, -15.510605302818359, 67.84815728399155] index 0
# df_frame_max [57, 47.5, -6.261578372004023, 67.95906002059706] index 0
# df_frame_max [58, 47.5, 0.0, 67.97262169965245] index 0
# df_frame_max [60, 47.5, -10.087070774294816, 67.9753815193547] index 0
# df_frame_max [61, 47.5, 110.12089463856853, 67.97574426127177] index 0
# df_frame_max [62, 47.5, 18.353473499239918, 67.9758276283142] index 2
# df_frame_max [63, 47.5, -26.05740038530471, 67.97582707550502] index 0
# df_frame_max [69, 47.5, 0.0, 67.97582621259734] index 0
# df_frame_max [70, 47.5, 24.471296493640367, 67.97582362079291] index 0
# df_frame_max [76, 47.5, -7.8172194209059205, 67.97582102899295] index 0
# df_frame_max [77, 47.5, -6.253775377761009, 67.97581930112636] index 0
# df_frame_max [82, 47.5, -10.422958742152067, 67.97581786123757] index 0
# df_frame_max [83, 47.5, 9.176735290944178, 67.9758169973043] index 0
# df_frame_max [84, 47.5, 18.3534701931184, 67.97581555741559] index 0
# df_frame_max [85, 47.5, -12.50754974875181, 67.97581382954914] index 0
# df_frame_max [86, 47.5, 12.235646432560312, 67.9758135415714] index 0
# df_frame_max [87, 47.5, -20.84591598298016, 67.97581296561593] index 0
# df_frame_max [90, 47.5, 146.82775470259614, 67.97581238966046] index 0
# df_frame_max [91, 47.5, -8.93396387916028, 67.97581210168273] index 0
# df_frame_max [92, 47.5, 0.0, 67.97581181370501] index 0
# df_frame_max [93, 47.5, 12.23564601787238, 67.97581123774955] index 0
# df_frame_max [94, 47.5, 4.078548655345464, 67.97581094977183] index 0
# df_frame_max [95, 47.5, -11.725827343017077, 67.9758106617941] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [117, 54.56, 0.0, 57.14285632653062] index 0
# df_frame_max [118, 54.56, -3.918367199533531, 64.93877321032076] index 0
# df_frame_max [119, 54.56, -1.7830319221691875, 64.29440560972307] index 0
# df_frame_max [126, 54.56, 66.66765615113371, 64.2856774004739] index 0
# df_frame_max [127, 54.56, -3.174644113002667, 64.28523728994539] index 0
# df_frame_max [129, 54.56, 16.6666701973262, 64.28569493725935] index 0
# df_frame_max [136, 54.56, -2.8571435357432096, 64.28568507872254] index 0
# df_frame_max [139, 54.56, 29.99999410789015, 64.28570048107781] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [117, 54.56, 0.0, 59.99999880000002] index 0
# df_frame_max [118, 54.56, -19.57499873550005, 64.49999581500016] index 1
# df_frame_max [119, 54.56, 0.0, 65.22899292135045] index 1
# df_frame_max [126, 54.56, 47.611193907816435, 65.2973916856026] index 0
# df_frame_max [127, 54.56, -6.588399003045084, 65.33105006407794] index 0
# df_frame_max [129, 54.56, 11.884329961302072, 65.34112883340435] index 0
# df_frame_max [136, 54.56, -5.939215662629778, 65.34453371537496] index 0
# df_frame_max [139, 54.56, 89.10893634938618, 65.34650569217347] index 4
#               day  us$      delta org. %     prob. org.
# df_frame_max [7, 56.6, 0.0, 99.99999500000027] index 0
# df_frame_max [8, 56.6, -4.722550091231084, 62.62626156871749] index 0
# df_frame_max [9, 56.6, -3.5080870259041554, 57.05725552348911] index 0
# df_frame_max [11, 56.6, 72.86167961038053, 56.382224006644876] index 0
# df_frame_max [44, 56.6, 6.891996555082576, 56.17447960543376] index 0
# df_frame_max [46, 56.6, 27.45233941115941, 56.029324172347536] index 0
# df_frame_max [48, 56.6, 24.008531196332754, 56.01172906593747] index 0
# df_frame_max [56, 56.6, -1.6001407895983242, 56.002018992643755] index 0
# df_frame_max [69, 56.6, 6.000151363505644, 56.000841505010435] index 0
# df_frame_max [94, 56.6, 60.00061992531911, 56.00034040770458] index 0
# df_frame_max [107, 56.6, -5.000028851144941, 56.00013643377939] index 0
# df_frame_max [108, 56.6, -1.3333344386890569, 56.00001480742927] index 0
# df_frame_max [109, 56.6, 240.00002826187145, 55.99999955575106] index 0
# df_frame_max [110, 56.6, 7.9999994030062895, 55.9999928762652] index 0
# df_frame_max [112, 56.6, -3.9999991431922624, 55.999988006197256] index 0
# df_frame_max [114, 56.6, -1.999999473427764, 55.99998582148037] index 0
# df_frame_max [115, 56.6, -5.7142841238478725, 55.99998498509989] index 0
# df_frame_max [116, 56.6, -1.3333329278520125, 55.999983545003715] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [7, 56.6, 0.0, 66.66666555555557] index 0
# df_frame_max [8, 56.6, -14.476190157037042, 64.3333318503704] index 0
# df_frame_max [9, 56.6, -11.656507393207074, 63.7975274978506] index 0
# df_frame_max [11, 56.6, 54.97394730567448, 63.80045299069048] index 0
# df_frame_max [44, 56.6, 5.23613169977703, 63.80099403972456] index 0
# df_frame_max [46, 56.6, 20.943762207029568, 63.800883543462476] index 0
# df_frame_max [48, 56.6, 21.990946902864785, 63.80089679492873] index 1
# df_frame_max [56, 56.6, -5.429863495923347, 63.80089637817426] index 0
# df_frame_max [69, 56.6, 4.581447297777522, 63.80089557633581] index 0
# df_frame_max [94, 56.6, 45.81447239403847, 63.80089479616308] index 0
# df_frame_max [107, 56.6, -16.968322927477875, 63.80089401625807] index 0
# df_frame_max [108, 56.6, -4.5248860035469916, 63.80089245639648] index 0
# df_frame_max [109, 56.6, 183.25788064597037, 63.80089167691183] index 0
# df_frame_max [110, 56.6, 6.108595946901803, 63.80089089744043] index 0
# df_frame_max [112, 56.6, -13.574657347271257, 63.80088933850572] index 0
# df_frame_max [114, 56.6, -6.787328507791403, 63.80088777956998] index 0
# df_frame_max [115, 56.6, -19.392366928197976, 63.800887000102136] index 0
# df_frame_max [116, 56.6, -4.524885506016714, 63.800885441166464] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [6, 67.8, 243.9755717166351, 69.56775881798235] index 1
# df_frame_max [7, 67.8, 48.35037534483855, 69.22619215116833] index 0
# df_frame_max [8, 67.8, 48.35032740417303, 69.22615104577736] index 0
# df_frame_max [9, 67.8, 12.087581731990179, 69.2261503641968] index 0
# df_frame_max [10, 67.8, 19.34013020037546, 69.22614832104374] index 0
# df_frame_max [23, 67.8, 36.26274305544183, 69.22614627789646] index 0
# df_frame_max [24, 67.8, -13.91721470434388, 69.22614559684739] index 0
# df_frame_max [25, 67.8, 48.35032264690628, 69.22614423474926] index 0
# df_frame_max [29, 67.8, 12.087580602267563, 69.22614389422472] index 0
# df_frame_max [30, 67.8, 12.087580423890548, 69.22614287265115] index 0
# df_frame_max [31, 67.8, 24.175160609945078, 69.22614219160211] index 0
# df_frame_max [32, 67.8, 0.0, 69.22614151055306] index 0
# df_frame_max [33, 67.8, -6.958606838729418, 69.22614048897952] index 0
# df_frame_max [50, 67.8, 24.17515965860103, 69.22613946740599] index 0
# df_frame_max [51, 67.8, 12.087579710382512, 69.226138786357] index 0
# df_frame_max [52, 67.8, -10.437909847340133, 69.22613776478349] index 0
# df_frame_max [53, 67.8, 0.0, 69.2261370837345] index 0
# df_frame_max [54, 67.8, 0.0, 69.22613640268551] index 0
# df_frame_max [85, 67.8, -10.437909539274646, 69.22613572163652] index 0
# df_frame_max [87, 67.8, 12.087579115792513, 69.22613538111204] index 0
# df_frame_max [90, 67.8, 24.17515811266703, 69.22613504058755] index 0
# df_frame_max [91, 67.8, -8.350327508193526, 69.22613470006308] index 0
# df_frame_max [94, 67.8, 16.116771916554022, 69.22613435953859] index 0
# df_frame_max [127, 67.8, 0.0, 69.22613401901411] index 0
# df_frame_max [130, 67.8, 19.34012610959604, 69.22613367848962] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [6, 67.8, 276.3131287337619, 70.75757508898073] index 1
# df_frame_max [7, 67.8, 47.47869097399646, 65.44260739512539] index 0
# df_frame_max [8, 67.8, 47.295692502044055, 65.31651042967201] index 0
# df_frame_max [9, 67.8, 11.824263179893764, 65.31548796786248] index 0
# df_frame_max [10, 67.8, 18.91891682011637, 65.31530952693369] index 0
# df_frame_max [23, 67.8, 35.472968601929445, 65.31530713992584] index 0
# df_frame_max [24, 67.8, -12.012010409335085, 65.31530649135986] index 0
# df_frame_max [25, 67.8, 47.29729006593155, 65.31530519659725] index 0
# df_frame_max [29, 67.8, 11.824322457897276, 65.3153048729556] index 0
# df_frame_max [30, 67.8, 11.824322282129323, 65.31530390205458] index 0
# df_frame_max [31, 67.8, 23.648644329902808, 65.3153032547857] index 0
# df_frame_max [32, 67.8, 0.0, 65.31530260751693] index 0
# df_frame_max [33, 67.8, -6.006004758310107, 65.31530163661378] index 0
# df_frame_max [50, 67.8, 23.64864339247911, 65.31530066571068] index 0
# df_frame_max [51, 67.8, 11.824321579061595, 65.31530001844193] index 0
# df_frame_max [52, 67.8, -9.009006780351376, 65.31529904753884] index 0
# df_frame_max [53, 67.8, 0.0, 65.31529840027012] index 0
# df_frame_max [54, 67.8, 0.0, 65.3152977530014] index 0
# df_frame_max [85, 67.8, -9.009006512516045, 65.3152971057327] index 0
# df_frame_max [87, 67.8, 11.824320993171805, 65.31529678209834] index 0
# df_frame_max [90, 67.8, 23.648641869165655, 65.31529645846399] index 0
# df_frame_max [91, 67.8, -7.207205102878706, 65.31529613482965] index 0
# df_frame_max [94, 67.8, 15.765761089873163, 65.3152958111953] index 0
# df_frame_max [127, 67.8, 0.0, 65.31529548756096] index 0
# df_frame_max [130, 67.8, 18.91891312036307, 65.3152951639266] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [117, 76.41, 0.0, 75.59523705746882] index 0
# df_frame_max [118, 76.41, -2.060295152704538, 63.24339062988228] index 1
# df_frame_max [119, 76.41, -4.761780994609914, 63.26703724963386] index 2
# df_frame_max [121, 76.41, 32.65286574045958, 63.266134902596896] index 0
# df_frame_max [123, 76.41, 9.795918688963713, 63.26530265338277] index 1
# df_frame_max [125, 76.41, 9.795917580370924, 63.265300906259135] index 0
# df_frame_max [126, 76.41, -10.204080503533355, 63.265299139727205] index 0
# df_frame_max [127, 76.41, 8.905379097214137, 63.265297202250736] index 0
# df_frame_max [128, 76.41, 0.0, 63.2652964275749] index 0
# df_frame_max [129, 76.41, 0.0, 63.26529526555923] index 0
# df_frame_max [130, 76.41, 16.326527745142698, 63.26529487822068] index 0
# df_frame_max [131, 76.41, -9.090907305357058, 63.265293716205065] index 0
# df_frame_max [132, 76.41, 48.97958173605312, 63.265292941528] index 0
# df_frame_max [133, 76.41, -5.714284417011646, 63.265291779512424] index 0
# df_frame_max [135, 76.41, 8.163263322800532, 63.26529061749686] index 0
# df_frame_max [137, 76.41, 0.0, 63.26528984281984] index 0
# df_frame_max [139, 76.41, 0.0, 63.26528906814283] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [117, 76.41, 0.0, 72.09876418019206] index 1
# df_frame_max [118, 76.41, -2.898367620850963, 71.6656661977034] index 1
# df_frame_max [119, 76.41, -3.380900733066119, 71.66070463931602] index 0
# df_frame_max [121, 76.41, 34.250356701890375, 71.6605865698413] index 0
# df_frame_max [123, 76.41, -10.142525081671442, 71.66058556446745] index 0
# df_frame_max [125, 76.41, 10.275106820107052, 71.66058379766713] index 0
# df_frame_max [126, 76.41, -14.489320825824663, 71.66058202099701] index 0
# df_frame_max [127, 76.41, 9.341005679019785, 71.66057980016033] index 0
# df_frame_max [128, 76.41, 0.0, 71.66057891182568] index 0
# df_frame_max [129, 76.41, 0.0, 71.66057757932371] index 0
# df_frame_max [130, 76.41, 17.125176441330275, 71.6605771351564] index 0
# df_frame_max [131, 76.41, -12.908666524676775, 71.66057580265446] index 0
# df_frame_max [132, 76.41, 51.37552773180922, 71.66057491431987] index 0
# df_frame_max [133, 76.41, -8.114018706906291, 71.66057358181797] index 0
# df_frame_max [135, 76.41, 8.562587636865228, 71.66057224931612] index 0
# df_frame_max [137, 76.41, 0.0, 71.66057136098155] index 0
# df_frame_max [139, 76.41, 0.0, 71.660570472647] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [6, 79.2, -4.444444429629629, 74.99999906250001] index 0
# df_frame_max [7, 79.2, 0.0, 61.550925024942124] index 0
# df_frame_max [8, 79.2, 0.0, 61.533398628537384] index 0
# df_frame_max [9, 79.2, -6.21204565894656, 61.533099428169535] index 0
# df_frame_max [10, 79.2, -3.623693241479627, 61.53309863276768] index 0
# df_frame_max [11, 79.2, 70.55748813244253, 61.53309824801272] index 0
# df_frame_max [44, 79.2, 62.71776692089699, 61.53309793969457] index 0
# df_frame_max [45, 79.2, -5.797909100950855, 61.53309763346666] index 0
# df_frame_max [56, 79.2, 47.03832472193676, 61.533097326884615] index 0
# df_frame_max [69, 79.2, 7.839720630741338, 61.533096100508956] index 0
# df_frame_max [70, 79.2, 0.0, 61.53309518072854] index 0
# df_frame_max [76, 79.2, 141.1149671346457, 61.53309426094813] index 0
# df_frame_max [77, 79.2, 0.0, 61.533093341167735] index 0
# df_frame_max [84, 79.2, -8.282726585491622, 61.53309242138736] index 0
# df_frame_max [85, 79.2, 56.44598488513243, 61.53309211479391] index 0
# df_frame_max [87, 79.2, -1.4494771380167668, 61.53309180820044] index 0
# df_frame_max [88, 79.2, -1.4494771235725001, 61.53309119501353] index 0
# df_frame_max [92, 79.2, -2.8989542182564665, 61.533090581826634] index 0
# df_frame_max [93, 79.2, -7.2473854734198335, 61.53308996863974] index 0
# df_frame_max [94, 79.2, 11.759579715658358, 61.5330896620463] index 0
# df_frame_max [95, 79.2, -6.0394878042398625, 61.53308904885941] index 0
# df_frame_max [107, 79.2, -5.435538996732877, 61.53308874226598] index 0
# df_frame_max [108, 79.2, 23.51915872820039, 61.533087822485655] index 0
# df_frame_max [109, 79.2, -10.353407354891205, 61.533087209298806] index 0
# df_frame_max [110, 79.2, 47.03831651891237, 61.53308659611194] index 0
# df_frame_max [111, 79.2, -7.2473850039811865, 61.53308598292509] index 0
# df_frame_max [112, 79.2, -2.415794965216398, 61.53308506314483] index 0
# df_frame_max [113, 79.2, 0.0, 61.53308414336456] index 0
# df_frame_max [114, 79.2, -5.435538563404907, 61.533083836771155] index 0
# df_frame_max [115, 79.2, 9.407662788163867, 61.53308322358433] index 0
# df_frame_max [116, 79.2, 18.815325295081237, 61.5330823038041] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [6, 79.2, -6.896551700356717, 74.0053047193043] index 0
# df_frame_max [7, 79.2, 0.0, 68.04677743111908] index 0
# df_frame_max [8, 79.2, 0.0, 67.30098836729182] index 0
# df_frame_max [9, 79.2, -9.66094082403796, 67.24870091774504] index 0
# df_frame_max [10, 79.2, -5.635760135256446, 67.24576612121793] index 0
# df_frame_max [11, 79.2, 67.05148261950373, 67.24498386212484] index 0
# df_frame_max [44, 79.2, 59.601667780419334, 67.24477438849209] index 0
# df_frame_max [45, 79.2, -9.017338202915305, 67.2447182187084] index 0
# df_frame_max [56, 79.2, 44.70133927296246, 67.24470296695394] index 0
# df_frame_max [69, 79.2, 7.450224198404388, 67.24469614285721] index 0
# df_frame_max [70, 79.2, 0.0, 67.24469511210766] index 0
# df_frame_max [76, 79.2, 134.104031722259, 67.2446941201742] index 0
# df_frame_max [77, 79.2, 0.0, 67.24469312898081] index 0
# df_frame_max [84, 79.2, -12.881914024334716, 67.24469213780154] index 0
# df_frame_max [85, 79.2, 53.641610844019404, 67.24469180740854] index 0
# df_frame_max [87, 79.2, -2.2543349321061514, 67.24469147701555] index 0
# df_frame_max [88, 79.2, -2.2543349099537267, 67.24469081622956] index 0
# df_frame_max [92, 79.2, -4.5086697756026055, 67.24469015544358] index 0
# df_frame_max [93, 79.2, -11.271674328244394, 67.2446894946576] index 0
# df_frame_max [94, 79.2, 11.175335153242303, 67.24468916426463] index 0
# df_frame_max [95, 79.2, -9.393061801751017, 67.24468850347866] index 0
# df_frame_max [107, 79.2, -8.45375558004012, 67.24468817308568] index 0
# df_frame_max [108, 79.2, 22.350669647592017, 67.24468718190676] index 0
# df_frame_max [109, 79.2, -16.102391185449818, 67.24468652112081] index 0
# df_frame_max [110, 79.2, 44.701338416660604, 67.24468586033487] index 0
# df_frame_max [111, 79.2, -11.27167360829065, 67.24468519954894] index 0
# df_frame_max [112, 79.2, -3.757224480715827, 67.24468420837006] index 0
# df_frame_max [113, 79.2, 0.0, 67.24468321719118] index 0
# df_frame_max [114, 79.2, -8.45375491546745, 67.24468288679823] index 0
# df_frame_max [115, 79.2, 8.940267200144254, 67.24468222601232] index 0
# df_frame_max [116, 79.2, 17.8805341367315, 67.2446812348335] index 0
#               day  us$      delta org. %     prob. org.
# df_frame_max [6, 95.0, -10.737249541370938, 67.9491945898028] index 4
# df_frame_max [7, 95.0, 0.0, 67.96848628868514] index 4
# df_frame_max [8, 95.0, 0.0, 67.96849014021879] index 1
# df_frame_max [9, 95.0, 0.0, 67.96849001702066] index 0
# df_frame_max [10, 95.0, 9.294387219942449, 67.96848835731453] index 0
# df_frame_max [23, 95.0, -5.374137950638772, 67.96848670215786] index 0
# df_frame_max [24, 95.0, 0.0, 67.96848559872024] index 0
# df_frame_max [25, 95.0, 46.471933459134505, 67.96848449528262] index 0
# df_frame_max [29, 95.0, -14.331033837063151, 67.96848339184503] index 0
# df_frame_max [30, 95.0, 46.47193157300749, 67.96848173668867] index 0
# df_frame_max [31, 95.0, 0.0, 67.96848063325112] index 0
# df_frame_max [32, 95.0, 15.490643291831079, 67.9684792539542] index 0
# df_frame_max [33, 95.0, -5.374137230853555, 67.96847759879795] index 0
# df_frame_max [83, 95.0, 92.94385522428203, 67.96847594364174] index 0
# df_frame_max [84, 95.0, -12.897928882916432, 67.96847511606366] index 0
# df_frame_max [85, 95.0, -10.748273981850343, 67.96847456434492] index 0
# df_frame_max [87, 95.0, 0.0, 67.96847428848555] index 0
# df_frame_max [90, 95.0, 23.235963145926135, 67.9684740126262] index 0
# df_frame_max [91, 95.0, -8.598619080784255, 67.96847373676684] index 0
# df_frame_max [93, 95.0, 9.294385182925383, 67.96847346090749] index 0
# df_frame_max [94, 95.0, -9.554021123318787, 67.96847318504814] index 0
# df_frame_max [95, 95.0, 7.74532092290026, 67.96847290918878] index 0
#
#
#               day  us$      delta search %    prob. search
# df_frame_max [6, 95.0, -13.354675250722439, 70.61586998311718] index 4
# df_frame_max [7, 95.0, 0.0, 70.61757970832568] index 4
# df_frame_max [8, 95.0, 0.0, 70.61757952580177] index 0
# df_frame_max [9, 95.0, 0.0, 70.61757890842178] index 0
# df_frame_max [10, 95.0, 8.780708375984872, 70.61757720551299] index 0
# df_frame_max [23, 95.0, -6.678508670635655, 70.61757550479788] index 0
# df_frame_max [24, 95.0, 0.0, 70.61757437098784] index 0
# df_frame_max [25, 95.0, 43.90353941277701, 70.61757323717784] index 0
# df_frame_max [29, 95.0, -17.80935559720683, 70.61757210336783] index 0
# df_frame_max [30, 95.0, 43.903537650528996, 70.61757040265286] index 0
# df_frame_max [31, 95.0, 0.0, 70.61756926884291] index 0
# df_frame_max [32, 95.0, 14.634512021501946, 70.61756785158049] index 0
# df_frame_max [33, 95.0, -6.678507786007187, 70.61756615086563] index 0
# df_frame_max [83, 95.0, 87.8070678996168, 70.61756445015081] index 0
# df_frame_max [84, 95.0, -16.028418107387758, 70.61756359979341] index 0
# df_frame_max [85, 95.0, -13.357014982262116, 70.6175630328885] index 0
# df_frame_max [87, 95.0, 0.0, 70.61756274943605] index 0
# df_frame_max [90, 95.0, 21.951766358117457, 70.61756246598358] index 0
# df_frame_max [91, 95.0, -10.685611857136475, 70.61756218253112] index 0
# df_frame_max [93, 95.0, 8.780706472757073, 70.61756189907867] index 0
# df_frame_max [94, 95.0, -11.872901968171478, 70.6175616156262] index 0
# df_frame_max [95, 95.0, 7.317255335222636, 70.61756133217374] index 0
#
#
#               DataFrames Format Presentation
#
#
#    day    us$  delta % Organic  prob % Organic  delta % search  prob % search
# 0