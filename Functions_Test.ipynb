# %% [markdown]
# <a href="https://colab.research.google.com/github/SuperChini/Brief-sample/blob/main/Functions_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
from vega_datasets import data
cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
cars[cars['Miles_per_Gallon']> 25.0]
# Out:
#                              Name  Miles_per_Gallon  Cylinders  Displacement  \
# 24                   datsun pl510              27.0          4          97.0
# 25   volkswagen 1131 deluxe sedan              26.0          4          97.0
# 29                       bmw 2002              26.0          4         121.0
# 35                   datsun pl510              27.0          4          97.0
# 36            chevrolet vega 2300              28.0          4         140.0
# ..                            ...               ...        ...           ...
# 401               ford mustang gl              27.0          4         140.0
# 402                     vw pickup              44.0          4          97.0
# 403                 dodge rampage              32.0          4         135.0
# 404                   ford ranger              28.0          4         120.0
# 405                    chevy s-10              31.0          4         119.0
#
# ...

# %%
import requests

if __name__ == '__main__':
  URL = 'https://www.binance.com/es/binance-api'
  response = requests.get(URL)
  print(response)
  if response.status_code == 200:
    print(response.content)
# Out:
# <Response [200]>
# ...

# %%
print('Ingrese el número que desea evaluar si es un número primo:')
nro = input() 
print('\n')
nro = int(nro) #Casteo del input a evaluar

def verificación_primo(nro):
  es_primo = True

  for i in range(2,nro):
    print('i = ', i)
    if nro % i == 0:
      es_primo = False
      print('El número', nro, 'testeado NO ES UN NÚMERO PRIMO y es divisible por', i)
  if (es_primo == True):
      print('el número', nro, 'testeado, es un número PRIMO') #excepción para cuando el nro es primo
  return
  
print(verificación_primo(nro))
# Out:
# Ingrese el número que desea evaluar si es un número primo:
# 12
#
#
# i =  2
# El número 12 testeado NO ES UN NÚMERO PRIMO y es divisible por 2
# i =  3
# El número 12 testeado NO ES UN NÚMERO PRIMO y es divisible por 3
# i =  4
# El número 12 testeado NO ES UN NÚMERO PRIMO y es divisible por 4
# i =  5
# i =  6
# El número 12 testeado NO ES UN NÚMERO PRIMO y es divisible por 6
# i =  7
# i =  8
# i =  9
# i =  10
# i =  11
# None
